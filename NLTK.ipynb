# %% [markdown]
# <a href="https://colab.research.google.com/github/kash2023k/Pytorch-Project1/blob/main/NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Natural Language Tookit**

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
print(nltk.__version__)
# Out:
# 3.9.1

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
example_string = "Google Colaboratory, or Google Colab for short, is a free, cloud-based Jupyter Notebook environment provided by Google. It allows users to write and execute Python code through the browser, especially suited for machine learning, data analysis, and education. Google Colab provides an online integrated development environment (IDE) for Python that requires no setup and runs entirely in the cloud"

# %%
# Break the string into multiple sentences
sent_tokenize(example_string)
# Out:
# ['Google Colaboratory, or Google Colab for short, is a free, cloud-based Jupyter Notebook environment provided by Google.',
#  'It allows users to write and execute Python code through the browser, especially suited for machine learning, data analysis, and education.',
#  'Google Colab provides an online integrated development environment (IDE) for Python that requires no setup and runs entirely in the cloud']

# %%
# Breaking into words
word_tokenize(example_string)
# Out:
# ['Google',
#  'Colaboratory',
#  ',',
#  'or',
#  'Google',
#  'Colab',
#  'for',
#  'short',
#  ',',
#  'is',
#  'a',
#  'free',
#  ',',
#  'cloud-based',
#  'Jupyter',
#  'Notebook',
#  'environment',
#  'provided',
#  'by',
#  'Google',
#  '.',
#  'It',
#  'allows',
#  'users',
#  'to',
#  'write',
#  'and',
#  'execute',
#  'Python',
#  'code',
#  'through',
#  'the',
#  'browser',
#  ',',
#  'especially',
#  'suited',
#  'for',
#  'machine',
#  'learning',
#  ',',
#  'data',
#  'analysis',
#  ',',
#  'and',
#  'education',
#  '.',
#  'Google',
#  'Colab',
#  'provides',
#  'an',
#  'online',
#  'integrated',
#  'development',
#  'environment',
#  '(',
#  'IDE',
#  ')',
#  'for',
#  'Python',
#  'that',
#  'requires',
#  'no',
#  'setup',
#  'and',
#  'runs',
#  'entirely',
#  'in',
#  'the',
#  'cloud']
